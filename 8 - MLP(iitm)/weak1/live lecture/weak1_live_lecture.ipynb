# %% [markdown]
# #### Introduction to pandas for Exploratory Data analysis

# %%
import pandas as pd

# %% [markdown]
# Series and DataFrame

# %%
d ={"name": "Hello" ,"age":20}

# %%
d
# Out:
# {'name': 'Hello', 'age': 20}

# %%
d={}
