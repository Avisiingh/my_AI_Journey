# %%
import pandas as pd

# %%
students_classes = {'Alice': 'Physics',
                   'Jack': 'Chemistry',
                   'Molly': 'English',
                   'Sam': 'History'}
s = pd.Series(students_classes)
s
# Out:
# Alice      Physics
# Jack     Chemistry
# Molly      English
# Sam        History
# dtype: object

# %%
s.iloc[3]
# Out:
# 'History'

# %%
s.loc["Molly"]
# Out:
# 'English'

# %%
s[3]
# Out:
# C:\Users\avina\AppData\Local\Temp\ipykernel_15972\3172538273.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s[3]
# 'History'

# %%
s["Molly"]
# Out:
# 'English'

# %%
class_code = {99: 'Physics',
              100: 'Chemistry',
              101: 'English',
              102: 'History'}
s = pd.Series(class_code)
s
# Out:
# 99       Physics
# 100    Chemistry
# 101      English
# 102      History
# dtype: object

# %%
s.iloc[0]
# Out:
# 'Physics'

# %%
s.loc[99]
# Out:
# 'Physics'

# %%
grades = pd.Series([90, 80, 70, 60])

total = 0
for grade in grades:
    total+=grade
print(total/len(grades))
# Out:
# 75.0

# %%
import numpy as np

# %%
total =np.sum(grades)
print(total /len(grades))
# Out:
# 75.0

# %%
numbers = pd.Series(np.random.randint(0,1000,10000))
numbers.head()
# Out:
# 0    506
# 1    200
# 2    748
# 3    288
# 4    817
# dtype: int32

# %%
len(numbers)
# Out:
# 10000

# %%
numbers.shape
# Out:
# (10000,)

# %%
# %%timeit -n 100
total = 0
for number in numbers:
    total+=number
total/len(numbers)
# Out:
# 1.17 ms ± 60.5 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n 100
total =np.sum(numbers)
total/len(numbers)
# Out:
# 37.7 μs ± 15.3 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
numbers.head()
# Out:
# 0    506
# 1    200
# 2    748
# 3    288
# 4    817
# dtype: int32

# %%
numbers +=2
numbers.head()
# Out:
# 0    508
# 1    202
# 2    750
# 3    290
# 4    819
# dtype: int32

# %%
s =pd.Series([1,2,3])
s.loc["history"] = 102
s
# Out:
# 0            1
# 1            2
# 2            3
# history    102
# dtype: int64

# %%
students_classes = pd.Series({'Alice': 'Physics',
                   'Jack': 'Chemistry',
                   'Molly': 'English',
                   'Sam': 'History'})
students_classes
# Out:
# Alice      Physics
# Jack     Chemistry
# Molly      English
# Sam        History
# dtype: object

# %%
kelly_classes = pd.Series(['Philosophy', 'Arts', 'Math'], index=['Kelly', 'Kelly', 'Kelly'])
kelly_classes
# Out:
# Kelly    Philosophy
# Kelly          Arts
# Kelly          Math
# dtype: object

# %%
all_students_classes = pd.concat([students_classes, kelly_classes])

# %%
all_students_classes
# Out:
# Alice       Physics
# Jack      Chemistry
# Molly       English
# Sam         History
# Kelly    Philosophy
# Kelly          Arts
# Kelly          Math
# dtype: object

# %%
students_classes
# Out:
# Alice      Physics
# Jack     Chemistry
# Molly      English
# Sam        History
# dtype: object

# %%
all_students_classes.loc["Kelly"]
# Out:
# Kelly    Philosophy
# Kelly          Arts
# Kelly          Math
# dtype: object
