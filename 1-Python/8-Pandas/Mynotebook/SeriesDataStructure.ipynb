# %%
import pandas as pd

# %%
student =["alice","jack","moly"]
pd.Series(student)
# Out:
# 0    alice
# 1     jack
# 2     moly
# dtype: object

# %%
numbers=[1,2,3]
pd.Series(numbers)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
students =["alice","jack",None]
pd.Series(students)
# Out:
# 0    alice
# 1     jack
# 2     None
# dtype: object

# %%
numbers=[1,2,None]
pd.Series(numbers)
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# dtype: float64

# %%
import numpy as np
np.nan ==None
# Out:
# False

# %%
np.isnan(np.nan)
# Out:
# np.True_

# %%
students_score ={"ALice" :"Physics",
                "Jack" : "Chemistry",
                "Molly" :"English" }

s =pd.Series(students_score)
s
# Out:
# ALice      Physics
# Jack     Chemistry
# Molly      English
# dtype: object

# %%
s.index
# Out:
# Index(['ALice', 'Jack', 'Molly'], dtype='object')

# %%
students =[("ALice","Brown"),("Jack","White"),("Molly","Green")]
pd.Series(students)
# Out:
# 0    (ALice, Brown)
# 1     (Jack, White)
# 2    (Molly, Green)
# dtype: object

# %%
s= pd.Series(["Physic","Chemistry","English"],index=["Alice","Jack","Molly"])

# %%
s
# Out:
# Alice       Physic
# Jack     Chemistry
# Molly      English
# dtype: object

# %%
students_score={
                "Alice" : "Physics",
                "Jack"  : "Chemistry",
                "Molly"  : "English"
}
s=  pd.Series(students_score,index=["Alice","Molly","Sam"])
s
# Out:
# Alice    Physics
# Molly    English
# Sam          NaN
# dtype: object
