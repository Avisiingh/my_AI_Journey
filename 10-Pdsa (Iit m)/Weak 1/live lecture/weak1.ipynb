# %%
def total(a,b):
    s = a + b   # 1 - unit
    return s    # 1 - unit

# %%
n = int(input())
s = 0                  # 1 - unit
for i in range(n):     # 0 to n -1 = n times
    s = s + i          # n times
print(s)               # 1 -unit

# f(x) = 1 + n + n +1 
# f(x) = 2 + 2n     we remove constant term here
# f(x)  = n

# %%
def total(n):  
    s = 0                     ## 1 - unit
    for i in range(n):        ## n times
        for j in range(n):    ## n^2
            s = s + 1         ## n^2
    return

# %% [markdown]
# #### Computing Gcd

# %%
def gcd(m,n):
