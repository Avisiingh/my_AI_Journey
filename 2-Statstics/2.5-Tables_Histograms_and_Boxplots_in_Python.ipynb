# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in d:\anaconda\envs\enev\lib\site-packages (from seaborn) (2.3.1)
# Collecting pandas>=1.2 (from seaborn)
#   Downloading pandas-2.3.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in d:\anaconda\envs\enev\lib\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in d:\anaconda\envs\enev\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\envs\enev\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\envs\enev\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\anaconda\envs\enev\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\envs\enev\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in d:\anaconda\envs\enev\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\anaconda\envs\enev\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\envs\enev\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas>=1.2->seaborn)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.2->seaborn)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in d:\anaconda\envs\enev\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading pandas-2.3.2-cp312-cp312-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 1.7 MB/s eta 0:00:07
#    -- ------------------------------------- 0.8/11.0 MB 1.5 MB/s eta 0:00:07
#    --- ------------------------------------ 1.0/11.0 MB 1.6 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.6/11.0 MB 1.7 MB/s eta 0:00:06
#    ------ --------------------------------- 1.8/11.0 MB 1.7 MB/s eta 0:00:06
#    ------- -------------------------------- 2.1/11.0 MB 1.6 MB/s eta 0:00:06
#    -------- ------------------------------- 2.4/11.0 MB 1.6 MB/s eta 0:00:06
#    --------- ------------------------------ 2.6/11.0 MB 1.6 MB/s eta 0:00:06
#    ----------- ---------------------------- 3.1/11.0 MB 1.6 MB/s eta 0:00:05
#    ------------ --------------------------- 3.4/11.0 MB 1.6 MB/s eta 0:00:05
#    -------------- ------------------------- 3.9/11.0 MB 1.6 MB/s eta 0:00:05
#    --------------- ------------------------ 4.2/11.0 MB 1.6 MB/s eta 0:00:05
#    ----------------- ---------------------- 4.7/11.0 MB 1.7 MB/s eta 0:00:04
#    ------------------- -------------------- 5.2/11.0 MB 1.7 MB/s eta 0:00:04
#    --------------------- ------------------ 5.8/11.0 MB 1.8 MB/s eta 0:00:03
#    --------------------- ------------------ 6.0/11.0 MB 1.8 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.6/11.0 MB 1.8 MB/s eta 0:00:03
#    ------------------------- -------------- 7.1/11.0 MB 1.8 MB/s eta 0:00:03
#    --------------------------- ------------ 7.6/11.0 MB 1.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.9/11.0 MB 1.9 MB/s eta 0:00:02
#    ------------------------------ --------- 8.4/11.0 MB 1.9 MB/s eta 0:00:02
#    -------------------------------- ------- 8.9/11.0 MB 1.9 MB/s eta 0:00:02
#    ---------------------------------- ----- 9.4/11.0 MB 1.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.0 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 10.2/11.0 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 2.0 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Installing collected packages: pytz, tzdata, pandas, seaborn
# Successfully installed pandas-2.3.2 pytz-2025.2 seaborn-0.13.2 tzdata-2025.2

# %%
import seaborn as sns # For plotting
import matplotlib.pyplot as plt # For showing plots

# %%
tips_data = sns.load_dataset("tips")

# %% [markdown]
# Visualizing the Data - Tables

# %%
tips_data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Describing Data
# - Summary statistics, including the mean, minimum, and maximum of the data, can be useful to get a feel for the central tendency and dispersion of each variable.

# %%
tips_data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# Creating a Histogram

# %%
sns.histplot(tips_data["total_bill"], kde = False).set_title("Histogram of Total Bill");

# %%
sns.histplot(tips_data["total_bill"], kde = False).set_title("Histogram of Total Bill");

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips_data);

# %%
sns.scatterplot(x="total_bill", y="tip", hue="sex", data=tips_data);

# %% [markdown]
# Creating a Boxplot

# %%
sns.boxplot(x=tips_data["total_bill"]).set_title("Box plot of the Total Bill");

# %%
sns.boxplot(x=tips_data["tip"]).set_title("Box plot of the Tip")
plt.show()

# %% [markdown]
# Creating histograms and boxplots stratified by groups

# %%
# Create a boxplot and histogram of the tips grouped by smoking status
sns.boxplot(x = tips_data["tip"], y = tips_data["smoker"])
plt.show()

# %%
# Create a boxplot and histogram of the tips grouped by time of day
sns.boxplot(x = tips_data["tip"], y = tips_data["time"])
# Out:
# <Axes: xlabel='tip', ylabel='time'>

# %%
g = sns.FacetGrid(tips_data, row = "time")
g = g.map(plt.hist, "tip")
plt.show()

# %%
sns.boxplot(x = tips_data["tip"], y = tips_data["day"])
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %%
g = sns.FacetGrid(tips_data, row = "day")
g = g.map(plt.hist, "tip")
plt.show()
