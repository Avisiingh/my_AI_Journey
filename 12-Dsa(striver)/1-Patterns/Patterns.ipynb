# %%
for i in range(0,5):
    for j in range(0,5):
        print("*",end="")
    print()
# Out:
# *****
# *****
# *****
# *****
# *****

# %%
for i in range(5):
    for j in range(0,i+1):
        print("*",end="")
    print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(0,5):
    for j in range(1,i+2):
        print(j,end="")
    print()
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %%
for i in range(1,6):
    for j in range(1,i+1):
        print(i,end="")
    print()
# Out:
# 1
# 22
# 333
# 4444
# 55555

# %%
for i in range(0,5):
    for j in range()
